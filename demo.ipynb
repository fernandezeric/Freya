# %%
# use the FreyaAPI from

# %%
import requests
import json
from astropy.io import ascii
from astropy.table import Table

# %%
def consulta_degree(ra,dec,radius,format,catalog):
    url = 'http://0.0.0.0:5000/get_lc'
    """
    url = 'http://0.0.0.0:5000/get_lc_nearest'
    """
    args = {'ra':ra,'dec':dec,'radius':radius,'format':format,'catalogs':catalog}
    r = requests.get(url=url,params=args)
    return r

# %%
# Use the FreyaAPI

# %%
rdg_junto = consulta_degree(139.33444972,68.6350604,0.0002777,'csv','ps1')

# %%
rdg_junto
# Out:
# <Response [200]>

# %%
tabla_juntotodo = ascii.read(rdg_junto.text,  format='csv', guess=False)
tabla_juntotodo
# Out:
# <Table length=132>
#        oid              detectID      filterID ... infoFlag2 infoFlag3 catalog
#       int64              int64         int64   ...   int64     int64     str3
# ------------------ ------------------ -------- ... --------- --------- -------
# 190361393344112894 153443866410000015        3 ...       128   7374912     ps1
# 190361393344112894 153445192410000017        3 ...       128   7374912     ps1
# 190361393344112894 153347716310000010        1 ...       128 124782656     ps1
# 190361393344112894 153348968310000008        1 ...       128 124782656     ps1
# 190361393344112894 153441340410000012        2 ...       128 124815424     ps1
# 190361393344112894 153442549410000013        2 ...       160     34880     ps1
# 190361393344112894 118025265260000028        4 ...       128   7374912     ps1
# 190361393344112894 118026233260000017        4 ...       128   7374912     ps1
# 190361393344112894 115636667260000047        5 ...       128  24119360     ps1
# ...

# %%
# if not use FreyaAPI and use the module python

# %%
from Freya.catalogs.core import GetData

# %%
# get_lc_deg_all
# get_lc_deg_nearest
# get_lc_hms_all
# get_lc_hms_nearest

# %%
data_ps1 = GetData(catalog='ps1',ra=139.33444972,dec=68.6350604,radius=0.00356,format='votable').get_lc_deg_all()

# %%
#data_ps1

# %%
data_ztf = GetData(catalog='ztf',ra=139.33444972,dec=68.6350604,radius=0.0002777,format='csv').get_lc_deg_all()

# %%
import io
from astropy.io.votable import parse,parse_single_table,from_table, writeto
votable = data_ps1.encode(encoding='UTF-8')
bio = io.BytesIO(votable)
votable = parse(bio)
table = parse_single_table(bio).to_table()
table
# Out:
# <Table length=75>
#        oid              detectID      filterID ...  infoFlag infoFlag2 infoFlag3
#                                                ...
#       int64              int64         uint8   ...   int64     int32     int32
# ------------------ ------------------ -------- ... --------- --------- ---------
# 190361393343891094 262444864030001447        2 ...  35651585         0  74481664
# 190361393343891094 262444188030000970        2 ...  35651585         0   7372800
# 190361393344112894 153443866410000015        3 ... 102760517       128   7374912
# 190361393344112894 153445192410000017        3 ... 102760517       128   7374912
# 190361393344112894 153347716310000010        1 ... 102760517       128 124782656
# 190361393344112894 153348968310000008        1 ... 102760517       128 124782656
# 190361393344112894 153441340410000012        2 ... 102760517       128 124815424
# 190361393344112894 153442549410000013        2 ... 102760517       160     34880
# ...

# %%
ascii.read(data_ps1,  format='csv', guess=False)
# Out:
# <Table length=75>
#        oid              detectID      filterID ...  infoFlag infoFlag2 infoFlag3
#       int64              int64         int64   ...   int64     int64     int64
# ------------------ ------------------ -------- ... --------- --------- ---------
# 190361393343891094 262444864030001447        2 ...  35651585         0  74481664
# 190361393343891094 262444188030000970        2 ...  35651585         0   7372800
# 190361393344112894 153443866410000015        3 ... 102760517       128   7374912
# 190361393344112894 153445192410000017        3 ... 102760517       128   7374912
# 190361393344112894 153347716310000010        1 ... 102760517       128 124782656
# 190361393344112894 153348968310000008        1 ... 102760517       128 124782656
# 190361393344112894 153441340410000012        2 ... 102760517       128 124815424
# 190361393344112894 153442549410000013        2 ... 102760517       160     34880
# ...

# %%
data_hms = GetData(catalog='ztf',hms='9h17m20.26793280000689s +4h34m32.414496000003936s',radius=0.0002777,format='votable').get_lc_hms_all()
# Out:
# No find the catalog : ztf

# %%
print(data_hms)
# Out:
# None

# %%
ascii.read(data_hms,  format='csv', guess=False)
# Out:
# <Table length=496>
#       oid         expid          hjd         ... exptime  airmass   programid
#      int64        int64        float64       ...  int64   float64     int64
# ---------------- -------- ------------------ ... ------- ---------- ---------
#  841108100002803 45020895 2458204.7103471234 ...      30 1.23399997         1
#  841108100002803 45025068  2458204.752069184 ...      30 1.24399996         1
#  841108100002803 45325025  2458207.751456796 ...      30 1.24899995         1
#  841108100002803 45331289 2458207.8140918068 ...      30 1.33299994         1
#  841108100002803 45625013 2458210.7511542714 ...      30      1.255         1
#  841108100002803 45625060  2458210.751617243 ...      30 1.25600004         1
#  841108100002803 47317651 2458227.6764497044 ...      30 1.23800004         1
#  841108100002803 48018374  2458234.683236291 ...      30      1.255         1
#  841108100002803 48023605   2458234.73553617 ...      30 1.32700002         1
# ...
